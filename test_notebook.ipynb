# %%
from HybridCnn import HybCNNTrainer

trainer = HybCNNTrainer(
                data_root="/Users/saracurti/Desktop/dataset_final",
                num_classes=3,
                batch_size=8,
                lr=1e-5,
                num_epochs=60,
                patience=20
            )

trainer.test_model("/Users/saracurti/myproject/Colposcopy/best_resnet18_roi.pth")
# Out:
# Device in uso: mps
# 🧪 Test finale → Loss: 1.1189 | Accuracy: 47.06% | ⚖️ Balanced Accuracy: 40.83%
#
# 📊 Report per classe:
#               precision    recall  f1-score   support
#
#           G1      0.500     0.657     0.568        35
#           G2      0.444     0.211     0.286        19
#          NEG      0.385     0.357     0.370        14
#
#     accuracy                          0.471        68
#    macro avg      0.443     0.408     0.408        68
# weighted avg      0.461     0.471     0.448        68

# %%
from Trainer import CNNTrainer
trainer = CNNTrainer(
data_root="/Users/saracurti/Desktop/dataset_final",
num_classes=3,
batch_size=8,
lr=1e-5,
num_epochs=60,
patience=20
)


trainer.test_model("/Users/saracurti/myproject/Colposcopy/best_cnn_model.pth")

# %%
from ViTTrainer import ViTTrainer
trainer = ViTTrainer(
            data_root="/Users/saracurti/Desktop/dataset_final",
            num_classes=3,
            batch_size=8,
            lr=1e-5,
            num_epochs=60,
            patience=20
        )


trainer.test_model("/Users/saracurti/myproject/Colposcopy/best_vit_model.pth")

# %%
from ViTTrainerNew import ViTTrainerScratch

trainer = ViTTrainerScratch(
        data_root="/Users/saracurti/Desktop/dataset_final",
        num_classes=3,
        batch_size=8,
        lr=1e-5,
        num_epochs=60,
        patience=20
    )


trainer.test_model("/Users/saracurti/myproject/Colposcopy/best_vit_scratch.pth")
